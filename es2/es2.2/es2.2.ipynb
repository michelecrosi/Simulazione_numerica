# %% [markdown]
# In questo esercizio calcolo il valore di $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$, ossia la radice della media (di un blocco) dei moduli quadri delle posizioni dei Random Walks, ad uno step fissato.
# Sono stati fatti M=$10^4$ Random Walks e ognuno di questi è composto da N=100 steps.
# $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ ed il suo errore sono stati stimati usando blocchi da 100 Random Walks.

# %% [markdown]
# # 2.2.1

# %% [markdown]
# In un reticolo cubico 3D di lato a=1

# %%
import matplotlib.pyplot as plt
import numpy as np

# M=10000           # Total number of random walks
# N=100                 # Number of blocks
# L=int(M/N)				# Number of random walks per block
# xx = np.arange(N)      # [0,1,2,...,N-1]
# print (type(f))

with open("out_RW_discr_err", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    xx=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                    xx.append(int(y))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
        
    # print(err)
with open("out_RW_discr", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    RW=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    RW.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")


bl=xx
# print(bl)
plt.plot(bl,RW)
plt.xlabel('#step')
plt.ylabel(r'$\sqrt{<|r|^2>_{RW}}$')
plt.grid(True)
plt.show()
plt.subplots()
plt.plot(bl,err)
plt.xlabel('#step')
plt.ylabel(r'$\sigma_{\sqrt{<|r|^2>_{RW}}}$')
plt.grid(True)
plt.show()
plt.subplots()

err=np.array(err)*20 #la moltiplicazione è definita solo su nparrray
plt.errorbar(bl,np.array(RW),yerr=err)#aumentato l'errore di un fattore 20 altrimenti non si vede
plt.xlabel('#step')
plt.ylabel(r'$\sqrt{<|r|^2>_{RW}}$')
plt.grid(True)
plt.show()
# plt.plot(np.array(bl),np.array(err)-(np.array(bl))**0.5)
# # plt.plot(bl,err-sqrt(bl))
# plt.xlabel('#step')
# plt.ylabel(r'$\sigma_{\sqrt{<|r|^2>_{RW}}}-\sqrt{\# steps}$')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Nell'ultimo grafico ho riscalato le barre degli errori di un fattore 20 per fare in modo si vedessero

# %% [markdown]
# A differenza degli scorsi esercizi non sto graficando la quantità da me osservata ($\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$) e il suo errore all'aumentare del numero di blocchi considerati, ma bensì in funzione del numero di passi. È quindi normale che non vi sia una convergenza ad un valore finito e anche che l'errore aumenti.
# All'aumentare dei passi infatti il percorso diventa sempre più ramificato e complicato rendendo così il modulo quadro della posizione sempre più grande e sempre più imprevedibile.

# %% [markdown]
# # 2.2.2

# %% [markdown]
# Facendo passi in una direzione 3D scelta con probabilità uniforme.

# %% [markdown]
# Ho aggiunto alla libreria random un estrattore di versori in $\mathbb{R} ^3$ che estrae uniformemente $\Phi \in [0;2\pi)$ ed estrae $\theta\in[0;\pi)$ usando la formula:
# $\theta=\arccos(1-2 y)$
# dove y come al solito è estratta uniformemente in $[0;1)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# M=10000           # Total number of random walks
# N=100                 # Number of blocks
# L=int(M/N)				# Number of random walks per block

with open("out_RW_cont_err", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    xx=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                    xx.append(int(y))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
        
    # print(err)
with open("out_RW_cont", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    RW=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    RW.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")


bl=xx
# print(bl)
plt.plot(bl,RW)
plt.xlabel('#step')
plt.ylabel(r'$\sqrt{<|r|^2>_{RW}}$')
plt.grid(True)
plt.show()
plt.subplots()
plt.plot(bl,err)
plt.xlabel('#step')
plt.ylabel(r'$\sigma_{\sqrt{<|r|^2>_{RW}}}$')
plt.grid(True)
plt.show()
plt.subplots()

err=np.array(err)*20 #la moltiplicazione è definita solo su nparrray
plt.errorbar(bl,np.array(RW),yerr=err)#aumentato l'errore di un fattore 20 altrimenti non si vede
plt.xlabel('#step')
plt.ylabel(r'$\sqrt{<|r|^2>_{RW}}$')
plt.grid(True)
plt.show()
# plt.plot(np.array(bl),np.array(err)-(np.array(bl))**0.5)
# # plt.plot(bl,err-sqrt(bl))
# plt.xlabel('#step')
# plt.ylabel(r'$\sigma_{\sqrt{<|r|^2>_{RW}}}-\sqrt{\# steps}$')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Nell'ultimo grafico ho riscalato le barre degli errori di un fattore 20 per fare in modo si vedessero

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit # per il fit

# funzione di fitting
def func(x, k):
    return k * np.sqrt(x)

with open("out_RW_discr_err", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    xx=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                    xx.append(int(y))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
        
print(err)
with open("out_RW_discr", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    RW=[]
    for i in righe:
            if(i!=""):
                try:
                    x,y=i.split("\t")
                    # print(i)
                    RW.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")

popt, pcov = curve_fit(func, xx, RW, sigma=err, absolute_sigma=True)

# Recupero il valore di k ottimale
k_opt = popt[0]

# Genero la curva fittata
x_fit = np.linspace(1, 10, 100)
y_fit = func(x_fit, k_opt)

# Creo il grafico
plt.figure(figsize=(8, 6))
plt.errorbar(xx, RW, yerr=err, fmt='o', label='Dati', color='blue', ecolor='black', elinewidth=3, capsize=0)
plt.plot(x_fit, y_fit, label=f'Fit: $y = {k_opt:.2f} \sqrt{{x}}$', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Fit dei dati con $f(x) = k \sqrt{x}$')
plt.show()


with open("out_RW_cont_err", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    xx=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                    xx.append(int(y))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
        
    # print(err)
with open("out_RW_cont", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    RW=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    RW.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")

popt, pcov = curve_fit(func, xx, RW, sigma=err, absolute_sigma=True)

# Recupero il valore di k ottimale
k_opt = popt[0]

# Genero la curva fittata
x_fit = np.linspace(1, 10, 100)
y_fit = func(x_fit, k_opt)

# Creo il grafico
plt.figure(figsize=(8, 6))
plt.errorbar(xx, RW, yerr=err, fmt='o', label='Dati', color='blue', ecolor='black', elinewidth=3, capsize=0)
plt.plot(x_fit, y_fit, label=f'Fit: $y = {k_opt:.2f} \sqrt{{x}}$', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Fit dei dati con $f(x) = k \sqrt{x}$')
plt.show()
# Out:
# [0.0, 0.00400492, 0.00566993, 0.0075003, 0.00869612, 0.00959159, 0.00979077, 0.0106081, 0.0106492, 0.0116848, 0.0123722, 0.0132694, 0.0141537, 0.0149768, 0.0156722, 0.0166083, 0.0165082, 0.0179475, 0.0176386, 0.0171769, 0.017284, 0.0182805, 0.0192381, 0.0197147, 0.0197472, 0.0195101, 0.0200882, 0.0204775, 0.0208458, 0.0219196, 0.0220961, 0.0228441, 0.0221332, 0.0217524, 0.02259, 0.0235376, 0.0244689, 0.0251747, 0.0254387, 0.0252767, 0.0251335, 0.0251825, 0.0262828, 0.0275382, 0.0279994, 0.0277495, 0.0288583, 0.0293053, 0.0281899, 0.0288813, 0.0287372, 0.0293824, 0.0294408, 0.0303265, 0.0312065, 0.0314975, 0.0323669, 0.0331521, 0.0335345, 0.0350033, 0.0351517, 0.0362238, 0.036136, 0.0372697, 0.0373317, 0.0360803, 0.0361357, 0.0371527, 0.0379017, 0.0388111, 0.0394721, 0.0388243, 0.0388209, 0.0389152, 0.0400307, 0.0407345, 0.0423743, 0.0421184, 0.0427814, 0.0426618, 0.0431385, 0.0442421, 0.0439628, 0.0446046, 0.0438828, 0.0437234, 0.0448721, 0.0439046, 0.0444681, 0.0453604, 0.0456859, 0
# ...

# %% [markdown]
# Si nota che entrambi i cammini hanno misurato un andamento di $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ che segue la legge: $\sqrt{\#steps}$.
