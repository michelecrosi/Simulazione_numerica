# %% [markdown]
# Assumiamo che il prezzo di un bene: S(t) al variare del tempo segua un moto Browniano Geometrico con volatilità: $\sigma=0.25$, tasso di interesse: $r=0.1$ e prezzo iniziale: $S(t=0)=100$.
# L'obbiettivo di questo esercizio è quello di calcolare il prezzo a cui bisogna vendere il diritto di call ($C[S(t=0),t=0]$) e quello di call ($P[S(t=0),t=0]$) se il questo diritto garantisce il prezzo $K=100$ al tempo $T=1$.
# Questi prezzi sono stimati basandosi sul fatto che il detentore del diritto (holder) agirà nel suo interesse e quindi si avvarrà del diritto solo se questo gli conviene.
# Valgono quindi:
# $C[S(t=0),t=0]=\exp(-rT)\max\{0, S(t=T)-K\}$
# $P[S(t=0),t=0]=\exp(-rT)\max\{0, K-S(t=T)\}$

# %% [markdown]
# Per simulare il moto Browniano Geometrico discretizzo il tempo in n intervalli e sfrutto che un moto di questo tipo può essere estratto a partire dalla formula:
# $$S(t_{i+1}) = S(t_i) \exp\left[ \left(\mu-\frac{1}{2}\sigma^2\right)(t_{i+1}-t_i)
# +\sigma Z_{i+1}\sqrt{t_{i+1}-t_i}\right]$$
# con $Z_i \sim \mathcal{N}(0,1)$
# (estratta con distribuzione gaussiana con media 0 e varianza 1)
# con $i\in \{0,...,n-1\}$ e $t_{n}=T$

# %% [markdown]
# # 3.1.1

# %% [markdown]
# In questo primo esercizio n=1 e quindi ho discretizzato il tempo in solo due momenti, quello iniziale e quello finale

# %%
import matplotlib.pyplot as plt
import numpy as np

# M=10000           # Total number of simulations
# N=100                 # Number of blocks
# L=int(M/N)


with open("out_err_C", 'r') as f:# err_con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    xx=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                    xx.append(int(y))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
        
    # print(err)
with open("out_C", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    C=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    C.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
bl=xx
# print(bl)
plt.errorbar(xx,np.array(C),yerr=err)
plt.xlabel('#blocchi')
plt.ylabel(r'$C[S(0),0]$')
plt.grid(True)
plt.show()


with open("out_err_P", 'r') as f:# err_con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
with open("out_P", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    P=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    P.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")

plt.errorbar(xx,np.array(P),yerr=err)
plt.xlabel('#blocchi')
plt.ylabel(r'$P[S(0),0]$')
plt.grid(True)
plt.show()

# %% [markdown]
# # 3.1.2

# %% [markdown]
# In questo esercizio n=100.

# %%
import matplotlib.pyplot as plt
import numpy as np

with open("out_err_C_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
with open("out_C_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    C100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    C100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
# print(bl)
plt.errorbar(xx,np.array(C100),yerr=err100)
plt.xlabel('#blocchi')
plt.ylabel(r'$C[S(0),0]$')
plt.grid(True)
plt.show()


with open("out_err_P_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
with open("out_P_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    P100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    P100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
# print(len(P100))
# print(len(xx))
plt.errorbar(xx,np.array(P100),yerr=err100)
plt.xlabel('#blocchi')
plt.ylabel(r'$P[S(0),0]$')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      29                     print(f"Il valore '{i}' non può essere convertito in due float.")
#      30 # print(bl)
# ---> 31 plt.errorbar(xx,np.array(C100),yerr=err100)
#      32 plt.xlabel('#blocchi')
#      33 plt.ylabel(r'$C[S(0),0]$')
#
# NameError: name 'xx' is not defined

# %% [markdown]
# ### For comparison, Black-Scholes analytic solution:

# %%
import scipy
from scipy.special import erf
import numpy
from numpy import exp
from numpy.lib.scimath import log, sqrt

# data
S0 = 100.
K = 100.
T = 1.
r = 0.1
sigma = 0.25
t=0

def N(x):
    return 0.5 * (1. + erf(x / sqrt(2.)))

def black_scholes(S0, K, T, r, sigma):
    d1 = 1./(sigma * sqrt(T)) * (log(S0 / K) + (r + (sigma**2) / 2.) * T)
    d2 = d1 - sigma * sqrt(T)
    C = S0 * N(d1) - K * exp(-r * T) * N(d2)
    P = S0 *(N(d1) - 1.) - K * exp(-r * T) * (N(d2)-1.)
    return C, P

if __name__ == "__main__":
    call, put = black_scholes(S0, K, T, r, sigma)
    print(" == BLACK-SCHOLES ==")
    print("call: ", call)
    print("put: ", put)
# Out:
#  == BLACK-SCHOLES ==
# call:  14.975790778311286
# put:  5.4595325819072364

# %%
import scipy
from scipy.special import erf
import numpy
from numpy import exp
from numpy.lib.scimath import log, sqrt
import matplotlib.pyplot as plt
import numpy as np


S0 = 100.
K = 100.
T = 1.
r = 0.1
sigma = 0.25
t=0

def N(x):
    return 0.5 * (1. + erf(x / sqrt(2.)))

def black_scholes(S0, K, T, r, sigma):
    d1 = 1./(sigma * sqrt(T)) * (log(S0 / K) + (r + (sigma**2) / 2.) * T)
    d2 = d1 - sigma * sqrt(T)
    C = S0 * N(d1) - K * exp(-r * T) * N(d2)
    P = S0 *(N(d1) - 1.) - K * exp(-r * T) * (N(d2)-1.)
    return C, P

call, put = black_scholes(S0, K, T, r, sigma)


with open("out_err_C", 'r') as f:# err_con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    xx=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                    xx.append(int(y))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
        
    # print(err)
with open("out_C", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    C=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    C.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
with open("out_err_C_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
with open("out_C_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    C100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    C100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
# print(bl)
plt.errorbar(xx,np.array(C100),yerr=err100, label="n=100")
bl=xx
plt.errorbar(xx,np.array(C),yerr=err, label="n=1")
plt.xlabel('#blocchi')
plt.ylabel(r'$C[S(0),0]$')
plt.grid(True)
teo = np.full(len(xx), call) # riempito un vettore con valori costanti
plt.plot(xx, teo, label="valore teorico")
plt.legend()
plt.show()


with open("out_err_P", 'r') as f:# err_con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in float.")
with open("out_P", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    P=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    P.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")

with open("out_err_P_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    err100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    err100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
with open("out_P_100", 'r') as f:# con with il file si chiude da solo appena finito 
    righe=f.read().split("\n")
    # print(righe)
    P100=[]
    for i in righe:
            if(i!=""):
                try:
                    # print(i.split("\t"))
                    x,y=i.split("\t")
                    # print(i)
                    P100.append(float(x))
                except ValueError:
                    print(f"Il valore '{i}' non può essere convertito in due float.")
# print(len(P100))
# print(len(xx))
plt.errorbar(xx,np.array(P),yerr=err, label="n=1")
teo = np.full(len(xx), put) # riempito un vettore con valori costanti
plt.plot(xx, teo, label="valore teorico")
plt.errorbar(xx,np.array(P100),yerr=err100, label="n=100")
plt.xlabel('#blocchi')
plt.ylabel(r'$P[S(0),0]$')
plt.grid(True)
plt.legend()
plt.show()

# print(P100[len(P100)-1])

print((abs(P100[len(P100)-1]-put)/err100[len(err100)-1]))
# Out:
# 1.4286269757451713

# %% [markdown]
# I risultati sembrano compatibili fra di loro e con il risultato teorico. Le previsioni differiscono dalla soluzione esatta di meno di 2 deviazioni standard. Reputo quindi che questa differenza sia dovuto a fenomeni statistici.
